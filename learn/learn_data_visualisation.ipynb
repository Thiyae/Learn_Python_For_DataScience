# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
os.getcwd()
# Out:
# 'C:\\Users\\thiya\\learn'

# %%
cars1=pd.read_csv('C:\\Users\\thiya\\learn/updated_cars.csv',index_col=0)

# %%
cars=cars1.copy()

# %%
cars
# Out:
#       Price   Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986   Diesel   90       1.0          0  2000      3
# 1     13750  23.0  72937   Diesel   90       1.0          0  2000      3
# 3     14950  26.0  48000   Diesel   90       0.0          0  2000      3
# 4     13750  30.0  38500   Diesel   90       0.0          0  2000      3
# 5     12950  32.0  61000   Diesel   90       0.0          0  2000      3
# ...     ...   ...    ...      ...  ...       ...        ...   ...    ...
# 1425   7950  80.0     ??   Petrol   86       1.0          0  1300      4
# 1429   8950  78.0  24000   Petrol   86       1.0          1  1300      5
# 1430   8450  80.0  23000   Petrol   86       0.0          0  1300      3
# 1432  10845  72.0     ??   Petrol   86       0.0          0  1300      3
# 1435   6950  76.0      1   Petrol  110       0.0          0  1600      5
#
#       Weight Price_Class  Age_Converted
# 0       1165        High            1.9
# ...

# %%
cars.isnull().sum()
# Out:
# Price              0
# Age              100
# KM                 0
# FuelType         100
# HP                 0
# MetColor         150
# Automatic          0
# CC                 0
# Doors              0
# Weight             0
# Price_Class        0
# Age_Converted    100
# dtype: int64

# %%
cars.dropna(axis=0,inplace=True)

# %%
cars.isnull().sum()
# Out:
# Price            0
# Age              0
# KM               0
# FuelType         0
# HP               0
# MetColor         0
# Automatic        0
# CC               0
# Doors            0
# Weight           0
# Price_Class      0
# Age_Converted    0
# dtype: int64

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1099 entries, 0 to 1435
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1099 non-null   int64
#  1   Age            1099 non-null   float64
#  2   KM             1099 non-null   float64
#  3   FuelType       1099 non-null   object
#  4   HP             1099 non-null   object
#  5   MetColor       1099 non-null   float64
#  6   Automatic      1099 non-null   int64
#  7   CC             1099 non-null   int64
#  8   Doors          1099 non-null   int64
#  9   Weight         1099 non-null   int64
#  10  Price_Class    1099 non-null   object
#  11  Age_Converted  1099 non-null   float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 111.6+ KB

# %%
cars.KM.replace("??",np.nan,inplace=True)
cars.KM.replace("????",np.nan,inplace=True)
cars.KM=cars.KM.astype('float')

# %% [markdown]
# **SCATTER PLOT**

# %% [markdown]
# scatter plot is mostly used to get interpret the correlation between variables

# %%
plt.scatter(cars.Age,cars.Price,c='red')
plt.title('Scatter plot of Price vs Age of the cars')
plt.xlabel('Age (months)')
plt.ylabel('Price (Euros)')
plt.show()

# %% [markdown]
# **HISTOGRAM**

# %% [markdown]
# Histogram often used to get the frequency distribution of numerical varibles

# %%
plt.hist(cars.KM)
# Out:
# (array([ 93., 239., 331., 223., 111.,  52.,  25.,  13.,  10.,   2.]),
#  array([1.000000e+00, 2.430090e+04, 4.860080e+04, 7.290070e+04,
#         9.720060e+04, 1.215005e+05, 1.458004e+05, 1.701003e+05,
#         1.944002e+05, 2.187001e+05, 2.430000e+05]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(cars.KM,color='green',edgecolor='white',bins=5)
plt.title('Histogram of Kilometer')
plt.xlabel('Kilometer')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **BAR PLOT**

# %% [markdown]
# To represent the frequency distribution of categorical variables

# %% [markdown]
# A bar diagram makes it easy to compare sets of data between different groups

# %%
cars.FuelType.value_counts()
# Out:
# FuelType
# Petrol    970
# Diesel    117
# CNG        12
# Name: count, dtype: int64

# %%
counts=cars.FuelType.value_counts()
fuelType=('Petro','Diesel','CNG')
index=np.arange(len(fuelType))
counts
# Out:
# FuelType
# Petrol    970
# Diesel    117
# CNG        12
# Name: count, dtype: int64

# %%
plt.bar(index,counts,color=['red','blue','cyan'])
plt.title('Bar plot of fuel types')
plt.xlabel('Fuel Types')
plt.ylabel('Frequency')
plt.xticks(index,fuelType,rotation=90)
plt.show()

# %% [markdown]
# **SeaBorn**

# %% [markdown]
# **1)Scatter Plot**

# %%
import seaborn as sns

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1099 entries, 0 to 1435
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1099 non-null   int64
#  1   Age            1099 non-null   float64
#  2   KM             1099 non-null   float64
#  3   FuelType       1099 non-null   object
#  4   HP             1099 non-null   object
#  5   MetColor       1099 non-null   float64
#  6   Automatic      1099 non-null   int64
#  7   CC             1099 non-null   int64
#  8   Doors          1099 non-null   int64
#  9   Weight         1099 non-null   int64
#  10  Price_Class    1099 non-null   object
#  11  Age_Converted  1099 non-null   float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 111.6+ KB

# %%
sns.set(style="darkgrid")# for themes
sns.regplot(x=cars.Age,y=cars.Price,marker='*',fit_reg=False)
# Out:
# <Axes: xlabel='Age', ylabel='Price'>

# %% [markdown]
# scatter plot of price vs age by fueltype

# %%
sns.lmplot(x='Age',y='Price',data=cars,fit_reg=False,hue='FuelType',legend=True,palette="Set1")

# %% [markdown]
# **HISTOGRAM**

# %%
sns.displot(cars.Age,kde=True,bins=5)

# %%
sns.displot(cars.Age,kde=False,bins=5)

# %% [markdown]
# ***BAR PLOT***

# %% [markdown]
# bar plot generally used to view the frequency distribution of fuel type of the cars

# %%
sns.countplot(x='FuelType',data=cars)
# Out:
# <Axes: xlabel='FuelType', ylabel='count'>

# %% [markdown]
# *group bar plot*

# %%
sns.countplot(x="FuelType",data=cars,hue="Automatic",legend=True)
# Out:
# <Axes: xlabel='FuelType', ylabel='count'>

# %% [markdown]
# ***BOXPLOT OR WHISKERS PLOT***

# %% [markdown]
# *used to visualize numerical distribution of data*

# %%
sns.boxplot(x=cars.Price)
# Out:
# <Axes: xlabel='Price'>

# %%
sns.boxplot(x=cars.Price,y=cars.FuelType)
# Out:
# <Axes: xlabel='Price', ylabel='FuelType'>

# %% [markdown]
# **grouped box**

# %%
sns.boxplot(x="FuelType",y=cars.Price,hue="Automatic",data=cars)
# Out:
# <Axes: xlabel='FuelType', ylabel='Price'>

# %% [markdown]
# ***Multiple plots in single plot***

# %%
f,(ax_box,ax_hist)=plt.subplots(2,gridspec_kw={"height_ratios":(.15,.85)})
sns.boxplot(cars.Price,ax=ax_box)
sns.distplot(cars.Price,ax=ax_hist,kde=False)
# Out:
# C:\Users\thiya\AppData\Local\Temp\ipykernel_10568\2331150903.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.Price,ax=ax_hist,kde=False)
# <Axes: xlabel='Price'>

# %% [markdown]
# **pairwise plot**

# %%
sns.pairplot(cars,kind="scatter",hue="FuelType")
plt.show()
